# %% [markdown]
# <a href="https://colab.research.google.com/github/Peter-O-O-V/Practically-learning-about-Variables/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# We are creating a box labeled 'player_name' and putting the text "Alex" inside.
Objective = "Learning about Variables"

# The computer looks in the 'Objective' box and prints:
print(Objective)
# Out:
# Learning about Variables
