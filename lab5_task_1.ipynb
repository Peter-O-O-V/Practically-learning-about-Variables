# %% [markdown]
# <a href="https://colab.research.google.com/github/Peter-O-O-V/Practically-learning-about-Variables/blob/main/lab5_task_1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
age = 28
print(f"Age: {age}, Type: {type(age)}")

price = 19.99
print(f"Price: {price}, Type: {type(price)}")

name = "Peter"
print(f"Name: {name}, Type: {type(name)}")

is_student_of_python = True
print(f"Is student of python: {is_student_of_python}, Type: {type(is_student_of_python)}")
# Out:
# Age: 28, Type: <class 'int'>
# Price: 19.99, Type: <class 'float'>
# Name: Peter, Type: <class 'str'>
# Is student of python: True, Type: <class 'bool'>
