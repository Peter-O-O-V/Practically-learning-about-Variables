# %%
name = "Peter"
print(f"Name: {name}, Type: {type(name)}")

is_self_taught_student_of_python = True
print(f"Is student of python: {is_self_taught_student_of_python}, Type: {type(is_self_taught_student_of_python)}")

with_help_from_Gemini_sha = True
print(f"with help from Gemini sha: {with_help_from_Gemini_sha}, Type: {type(with_help_from_Gemini_sha)}")

price_paid_for_Gemini_is = 1.92
print(f"I sha paid, which is very expensive as a Nigerian: {price_paid_for_Gemini_is}, Type: {type(price_paid_for_Gemini_is)}")
# Out:
# Name: Peter, Type: <class 'str'>
# Is student of python: True, Type: <class 'bool'>
# with help from Gemini sha: True, Type: <class 'bool'>
# I sha paid, which is very expensive as a Nigerian: 1.92, Type: <class 'float'>
