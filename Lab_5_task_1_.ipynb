# %%
name = "Peter"
print (f"Name:{name}, Type:{type(name)}")

is_a_self_taught_student_of_python = True
print (f"Is a self taught student of python: {is_a_self_taught_student_of_python}, Type:{type(is_a_self_taught_student_of_python)}")

With_the_help_of_google = True
print (f"with the help of google gemini of course:{With_the_help_of_google}, Type:{type(With_the_help_of_google)}")

Price_paid_for_Gemini = 1.92
print (f"I sha paid, which is very expensive as a Nigerian:{Price_paid_for_Gemini}, Type: {type(Price_paid_for_Gemini)} ")

that_is_the_end = 0
print (f"the end: {that_is_the_end}, Type: {type(that_is_the_end)}")
# Out:
# Name:Peter, Type:<class 'str'>
# Is a self taught student of python: True, Type:<class 'bool'>
# with the help of google gemini of course:True, Type:<class 'bool'>
# I sha paid, which is very expensive as a Nigerian:1.92, Type: <class 'float'>
# the end: 0, Type: <class 'int'>
