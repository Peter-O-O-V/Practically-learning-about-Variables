# %%
# Setting the initial score
score = 0
print("Starting score:", score)

# The player collects a coin, so we update the variable
score = 50
print("New score:", score)
# Out:
# Starting score: 0
# New score: 50

# %%
health = 100

# The player takes 27 damage.
# We take the current health (100), subtract 27, and put the new number (73) back in the box.
health = health - 27

print("Current health:", health)
# Out:
# Current health: 73
